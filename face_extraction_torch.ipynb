# %% [markdown]
# # CCM-109 - Tópicos especiais de IA - Deep Learning
#
# ## Pipeline de extração de rostos por frame
#
# [![Abrir no Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jtlimo/ccm-109/blob/main/face_extraction_torch.ipynb)
#
# ---
#
# ### Índice
#
# 1. [Configuração](#1-configuração)
# 2. [Funções auxiliares](#2-funções-auxiliares)
# 3. [Execução pipeline](#3-execução-da-pipeline)

# %% [markdown]
# ## 1. Configuração

# %%
# @title Instalar dependências

# %pip install tqdm tf-keras
# %pip install Pillow torch torchvision facenet-pytorch ipywidgets
# %pip install "numpy<2"
# %pip install opencv-python==4.10.0.84

# %% [markdown]
# ## 2. Funções auxiliares

# %%
# @title Pipeline do dataset
import preprocess_macos as pi
from collections import defaultdict
from pathlib import Path

from tqdm import tqdm


def process_dataset(dataset_root, output_base= "/Volumes/Expansion/dataset/FF/frames"):
    dataset_root = Path(dataset_root)
    output_base = Path(output_base)

    videos_by_folder = defaultdict(list)
    for v in Path(dataset_root).rglob("*.mp4"):
     if "frames" in v.parts:
        continue
     if not v.name.startswith("._") and not v.name.startswith(".DS_Store"):
        videos_by_folder[v.parent].append(v)

    total_frames = total_videos = 0
    folder_stats = {}

    for folder, files in videos_by_folder.items():
        relative_folder = folder.relative_to(dataset_root)
        out_folder = output_base / relative_folder

        folder_frames = 0
        desc_name = str(relative_folder)[-20:]
        for v in tqdm(files, desc=desc_name, unit="vid"):
            folder_frames += pi.process_video(v, out_folder)
            total_videos += 1

        folder_stats[str(relative_folder)] = {"videos": len(files), "frames": folder_frames}
        total_frames += folder_frames

    print(f"\nPastas: {len(videos_by_folder)} | Videos: {total_videos} | Frames: {total_frames}")
    return folder_stats

# %% [markdown]
# ## 3. Execução da pipeline

# %%
# @title Executar pipeline

stats = process_dataset("/Volumes/Expansion/dataset/FF")
# Out:
# ...
# es/actors/c23/videos: 100%|██████████| 363/363 [1:02:34<00:00, 10.34s/vid]
# Pastas: 8 | Videos: 9431 | Frames: 269102
